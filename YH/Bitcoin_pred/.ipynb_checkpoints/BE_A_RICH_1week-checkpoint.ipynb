# %%
import pandas as pd
import numpy as np


df = pd.read_csv('./bitcoin.csv', encoding='utf-8')
df
# Out:
#                  날짜        종가        오픈        고가        저가      거래량     변동 %
# 0     2022년 06월 17일  20,531.8  20,391.3  21,315.4  20,244.1  141.70K    0.71%
# 1     2022년 06월 16일  20,386.6  22,577.9  22,942.1  20,231.1  144.00K   -9.71%
# 2     2022년 06월 15일  22,577.9  22,137.5  22,754.4  20,125.8  280.41K    1.90%
# 3     2022년 06월 14일  22,157.3  22,449.1  23,200.3  20,860.9  251.01K   -1.29%
# 4     2022년 06월 13일  22,448.0  26,606.3  26,857.6  22,006.3  379.26K  -15.63%
# ...             ...       ...       ...       ...       ...      ...      ...
# 1989  2017년 01월 05일     989.3   1,135.4   1,150.6     874.5  240.01K  -12.86%
# 1990  2017년 01월 04일   1,135.4   1,033.3   1,148.5   1,022.3  156.27K    9.88%
# 1991  2017년 01월 03일   1,033.3   1,017.0   1,035.5   1,006.5   54.79K    1.60%
# 1992  2017년 01월 02일   1,017.0     995.4   1,031.7     990.2   64.95K    2.17%
# 1993  2017년 01월 01일     995.4     963.4   1,001.6     956.1   41.15K    3.33%
#
# [1994 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      1994 non-null   object
#  1   종가      1994 non-null   object
#  2   오픈      1994 non-null   object
#  3   고가      1994 non-null   object
#  4   저가      1994 non-null   object
#  5   거래량     1994 non-null   object
#  6   변동 %    1994 non-null   object
# dtypes: object(7)
# memory usage: 109.2+ KB

# %%
def datetime(date):
    new_date1 = date.replace('년 ', '-')
    new_date2 = new_date1.replace('월 ', '-')
    new_date3 = new_date2.replace('일', '')
    return new_date3

def price(price):
    new_price = price.replace(',', '')
    return new_price

# %%
df_temp = df.copy()
df_temp['날짜'] = df['날짜'].apply(datetime)
feature = ['종가', '오픈', '고가', '저가']
for i in feature:
    df_temp[i] = df[i].apply(price)
df_temp['거래량'] = df_temp['거래량'].apply(lambda x:x[:-1])
df_temp['변동 %'] = df_temp['변동 %'].apply(lambda x:x[:-1])
df_temp.columns = ['date', 'close', 'open', 'high', 'low', 'volume K', 'rate %']
df_temp
# Out:
#             date    close     open     high      low volume K  rate %
# 0     2022-06-17  20531.8  20391.3  21315.4  20244.1   141.70    0.71
# 1     2022-06-16  20386.6  22577.9  22942.1  20231.1   144.00   -9.71
# 2     2022-06-15  22577.9  22137.5  22754.4  20125.8   280.41    1.90
# 3     2022-06-14  22157.3  22449.1  23200.3  20860.9   251.01   -1.29
# 4     2022-06-13  22448.0  26606.3  26857.6  22006.3   379.26  -15.63
# ...          ...      ...      ...      ...      ...      ...     ...
# 1989  2017-01-05    989.3   1135.4   1150.6    874.5   240.01  -12.86
# 1990  2017-01-04   1135.4   1033.3   1148.5   1022.3   156.27    9.88
# 1991  2017-01-03   1033.3   1017.0   1035.5   1006.5    54.79    1.60
# 1992  2017-01-02   1017.0    995.4   1031.7    990.2    64.95    2.17
# 1993  2017-01-01    995.4    963.4   1001.6    956.1    41.15    3.33
#
# [1994 rows x 7 columns]

# %%
df_temp['date'] = pd.to_datetime(df_temp['date'])
df_temp[['close', 'open', 'high', 'low', 'volume K', 'rate %']] = df_temp[['close', 'open', 'high', 'low', 'volume K', 'rate %']].astype(float)
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      1994 non-null   datetime64[ns]
#  1   close     1994 non-null   float64
#  2   open      1994 non-null   float64
#  3   high      1994 non-null   float64
#  4   low       1994 non-null   float64
#  5   volume K  1994 non-null   float64
#  6   rate %    1994 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 109.2 KB

# %%
df_temp = df_temp.sort_values(by='date')
df_temp = df_temp.set_index('date')
df_temp
# Out:
#               close     open     high      low  volume K  rate %
# date
# 2017-01-01    995.4    963.4   1001.6    956.1     41.15    3.33
# 2017-01-02   1017.0    995.4   1031.7    990.2     64.95    2.17
# 2017-01-03   1033.3   1017.0   1035.5   1006.5     54.79    1.60
# 2017-01-04   1135.4   1033.3   1148.5   1022.3    156.27    9.88
# 2017-01-05    989.3   1135.4   1150.6    874.5    240.01  -12.86
# ...             ...      ...      ...      ...       ...     ...
# 2022-06-13  22448.0  26606.3  26857.6  22006.3    379.26  -15.63
# 2022-06-14  22157.3  22449.1  23200.3  20860.9    251.01   -1.29
# 2022-06-15  22577.9  22137.5  22754.4  20125.8    280.41    1.90
# 2022-06-16  20386.6  22577.9  22942.1  20231.1    144.00   -9.71
# 2022-06-17  20531.8  20391.3  21315.4  20244.1    141.70    0.71
#
# [1994 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
df_temp['close'].plot()
plt.show()

# %%
import seaborn as sns

sns.heatmap(df_temp.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df_temp = df_temp.reset_index()
df_temp
# Out:
#            date    close     open     high      low  volume K  rate %
# 0    2017-01-01    995.4    963.4   1001.6    956.1     41.15    3.33
# 1    2017-01-02   1017.0    995.4   1031.7    990.2     64.95    2.17
# 2    2017-01-03   1033.3   1017.0   1035.5   1006.5     54.79    1.60
# 3    2017-01-04   1135.4   1033.3   1148.5   1022.3    156.27    9.88
# 4    2017-01-05    989.3   1135.4   1150.6    874.5    240.01  -12.86
# ...         ...      ...      ...      ...      ...       ...     ...
# 1989 2022-06-13  22448.0  26606.3  26857.6  22006.3    379.26  -15.63
# 1990 2022-06-14  22157.3  22449.1  23200.3  20860.9    251.01   -1.29
# 1991 2022-06-15  22577.9  22137.5  22754.4  20125.8    280.41    1.90
# 1992 2022-06-16  20386.6  22577.9  22942.1  20231.1    144.00   -9.71
# 1993 2022-06-17  20531.8  20391.3  21315.4  20244.1    141.70    0.71
#
# [1994 rows x 7 columns]

# %%
df_temp['year'] = df_temp.date.dt.year
df_temp['month'] = df_temp.date.dt.month
df_temp['day'] = df_temp.date.dt.day

df_temp
# Out:
#            date    close     open     high      low  volume K  rate %  year  \
# 0    2017-01-01    995.4    963.4   1001.6    956.1     41.15    3.33  2017
# 1    2017-01-02   1017.0    995.4   1031.7    990.2     64.95    2.17  2017
# 2    2017-01-03   1033.3   1017.0   1035.5   1006.5     54.79    1.60  2017
# 3    2017-01-04   1135.4   1033.3   1148.5   1022.3    156.27    9.88  2017
# 4    2017-01-05    989.3   1135.4   1150.6    874.5    240.01  -12.86  2017
# ...         ...      ...      ...      ...      ...       ...     ...   ...
# 1989 2022-06-13  22448.0  26606.3  26857.6  22006.3    379.26  -15.63  2022
# 1990 2022-06-14  22157.3  22449.1  23200.3  20860.9    251.01   -1.29  2022
# 1991 2022-06-15  22577.9  22137.5  22754.4  20125.8    280.41    1.90  2022
# 1992 2022-06-16  20386.6  22577.9  22942.1  20231.1    144.00   -9.71  2022
# 1993 2022-06-17  20531.8  20391.3  21315.4  20244.1    141.70    0.71  2022
#
#       month  day
# 0         1    1
# 1         1    2
# 2         1    3
# 3         1    4
# 4         1    5
# ...     ...  ...
# 1989      6   13
# 1990      6   14
# 1991      6   15
# 1992      6   16
# 1993      6   17
#
# [1994 rows x 10 columns]

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='year', y='close', data=df_temp)
# Out:
# <AxesSubplot:xlabel='year', ylabel='close'>

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='month', y='close', data=df_temp)
# Out:
# <AxesSubplot:xlabel='month', ylabel='close'>

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='day', y='close', data=df_temp)
# Out:
# <AxesSubplot:xlabel='day', ylabel='close'>

# %%
def plot_by_time(string, numb):
    plt.figure(figsize=(10,5))
    if string == 'year':
        temp_df = df_temp[df_temp['date'].dt.year == numb]
        temp_df['close'].plot()
        plt.title('{} year'.format(i))
        plt.show()
    elif string == 'month': 
        temp_df = df_temp[df_temp['date'].dt.month == numb]
        temp_df['close'].plot()
        plt.title('{} month'.format(i))
        plt.show()
    elif string == 'day': 
        temp_df = df_temp[df_temp['date'].dt.day == numb]
        temp_df['close'].plot()
        plt.title('{} day'.format(i))
        plt.show()

# %% [markdown]
# ## 년도별 plot

# %%
for i in df_temp['date'].dt.year.unique():
    plot_by_time('year', i)

# %% [markdown]
# ## IDEA

# %% [markdown]
# 1. 이동평균선(MA)을 구해서 변수에 추가
# - 단기 : 5일선
# - 중기 : 20일선, 60일선
# - 장기 : 120일선
#
# 2. 데드크로스, 골든크로스 변수로 구현
# - 데드크로스 : 단기이평선이 장기이평선을 뚫고 내려가는 지점
# - 골든크로스 : 단기이평선이 장기이평선을 뚫고 올라가는 지점
#
# 3. 지지선과 저항선 추세선 변수로 구현
# - 단기 지지/저항선과 장기 지지/저항선을 따로 변수로 만들어야 할듯
#
# 4. 탐욕지수 (greed index) 데이터화 시킬 수 있으면 변수로 추가
#
# 5. 엘리엇 파동기법 넣을 수 있을까?
#
# 6. 가격의 패턴(ex. 삼각수렴)을 표현할 수 있을까?

# %%
df = df_temp
df
# Out:
#            date    close     open     high      low  volume K  rate %  year  \
# 0    2017-01-01    995.4    963.4   1001.6    956.1     41.15    3.33  2017
# 1    2017-01-02   1017.0    995.4   1031.7    990.2     64.95    2.17  2017
# 2    2017-01-03   1033.3   1017.0   1035.5   1006.5     54.79    1.60  2017
# 3    2017-01-04   1135.4   1033.3   1148.5   1022.3    156.27    9.88  2017
# 4    2017-01-05    989.3   1135.4   1150.6    874.5    240.01  -12.86  2017
# ...         ...      ...      ...      ...      ...       ...     ...   ...
# 1989 2022-06-13  22448.0  26606.3  26857.6  22006.3    379.26  -15.63  2022
# 1990 2022-06-14  22157.3  22449.1  23200.3  20860.9    251.01   -1.29  2022
# 1991 2022-06-15  22577.9  22137.5  22754.4  20125.8    280.41    1.90  2022
# 1992 2022-06-16  20386.6  22577.9  22942.1  20231.1    144.00   -9.71  2022
# 1993 2022-06-17  20531.8  20391.3  21315.4  20244.1    141.70    0.71  2022
#
#       month  day
# 0         1    1
# 1         1    2
# 2         1    3
# 3         1    4
# 4         1    5
# ...     ...  ...
# 1989      6   13
# 1990      6   14
# 1991      6   15
# 1992      6   16
# 1993      6   17
#
# [1994 rows x 10 columns]

# %%
plt.figure(figsize=(15,7))
# Line Graph by matplotlib with wide-form DataFrame

plt.plot(df.date, df.close, marker='s', color='r')
plt.plot(df.date, df.high, marker='o', color='g')
plt.plot(df.date, df.low, marker='*', color='b')
plt.plot(df.date, df.open, marker='+', color='y')

plt.title('BITCOIN', fontsize=20) 
plt.ylabel('PRICE', fontsize=14)
plt.xlabel('DATE', fontsize=14)
plt.legend(['Close', 'High', 'Low', 'Open'], fontsize=12, loc='best')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
_ = plt.hist(df.close, 100, density=True, alpha=0.75)

# %%
# z-test로 p-value 확인

from statsmodels.stats.weightstats import ztest

_, p = ztest(df.close)
print(p)  # 0
# Out:
# 0.0

# %% [markdown]
# - p value 0.05 이하이므로 정규분포와는 거리가 멀다는 의미로 해석할 수 있다.
# - 즉, 이 데이터로 정규분포를 가정한 신뢰구간 분석은 적용하기 어렵

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# 단기이평선 값인 5일을 기준으로 도출
# extrapolate_trend='freq' : Trend 성분을 만들기 위한 rolling window 때문에 필연적으로 trend, resid에는 Nan 값이 발생하기 때문에, 이 NaN값을 채워주는 옵션이다.
result = seasonal_decompose(df.close, model='additive', two_sided=True, 
                            period=5, extrapolate_trend='freq') 
plt.figure(figsize=(15,10))
result.plot()
plt.show()

# %% [markdown]
# ### 시계열 분해
#
# - additive 방법
#     - Observed[t] = trend[t] + seasonal[t] + resid[t]
# - multiplicative 방법
#     - Observed[t] = trend[t] x seasonal[t] x resid[t]
#       위 식의 양변에 로그를 취하면 결과적으로 additive와 동일한 결과가 얻어진다.
#
# > 잔차는 평균 0을 기준으로 분포하고 있으므로, 잔차가 큰 날은 일반적인 추세나 게절성에서 벗어난 날이다.

# %%
fig, ax = plt.subplots(figsize=(9,6))
_ = plt.hist(result.resid, 100, density=True, alpha=0.75)

# %%
r = result.resid.values
st, p = ztest(r)
print(st,p)  # 0.13945750234754367 0.8890886359287032
# Out:
# 0.13945750234742457 0.8890886359287974

# %% [markdown]
# - p-value가 0.05 이상으로 나오므로, 잔차는 정규분포를 잘 따르고 있다고 판단

# %% [markdown]
# ### 잔차(residual)가 큰 날짜의 데이터 확인 (이상치)

# %%
# 평균과 표준편차 출력
mu, std = result.resid.mean(), result.resid.std()
print("평균:", mu, "표준편차:", std)
# 평균: 1.9089768239690312 표준편차: 611.2534875222074

# 3-sigma(표준편차)를 기준으로 이상치 판단
print("이상치 갯수:", len(result.resid[(result.resid>mu+3*std)|(result.resid<mu-3*std)]))
# Out:
# 평균: 1.9089768239673923 표준편차: 611.2534875222035
# 이상치 갯수: 54

# %%
print([i for i in df.date[result.resid[(result.resid>mu+3*std)|(result.resid<mu-3*std)].index]])
# Out:
# [Timestamp('2017-12-07 00:00:00'), Timestamp('2021-01-12 00:00:00'), Timestamp('2021-01-14 00:00:00'), Timestamp('2021-01-21 00:00:00'), Timestamp('2021-01-27 00:00:00'), Timestamp('2021-02-07 00:00:00'), Timestamp('2021-02-08 00:00:00'), Timestamp('2021-02-21 00:00:00'), Timestamp('2021-02-23 00:00:00'), Timestamp('2021-02-28 00:00:00'), Timestamp('2021-03-13 00:00:00'), Timestamp('2021-03-15 00:00:00'), Timestamp('2021-03-25 00:00:00'), Timestamp('2021-04-07 00:00:00'), Timestamp('2021-04-25 00:00:00'), Timestamp('2021-04-29 00:00:00'), Timestamp('2021-05-04 00:00:00'), Timestamp('2021-05-11 00:00:00'), Timestamp('2021-05-12 00:00:00'), Timestamp('2021-05-19 00:00:00'), Timestamp('2021-05-23 00:00:00'), Timestamp('2021-06-03 00:00:00'), Timestamp('2021-06-08 00:00:00'), Timestamp('2021-06-12 00:00:00'), Timestamp('2021-06-21 00:00:00'), Timestamp('2021-09-06 00:00:00'), Timestamp('2021-09-07 00:00:00'), Timestamp('2021-09-19 00:00:00'), Timestamp('2021-09-21 00:00:00'), Timestamp('2021-09-23 00:00:00'), Timestamp('2021-10-01 00:00:00'), Timestamp('2021-10-06 00:00:00'), Timestamp('2021-10-15 00:00:00'), Timestamp('2021-10-20 00:00:00'), Timestamp('2021-10-25 00:00:00'), Timestamp('2021-10-27 00:00:00'), Timestamp('2021-11-08 00:00:00'), Timestamp('2021-11-14 00:00:00'), Timestamp('2021-11-18 00:00:00'), Timestamp('2021-11-25 00:00:00'), Timestamp('2021-11-26 00:00:00'), Timestamp('2021-12-02 00:00:00'), Timestamp('2021-12-04 00:00:00'), Timestamp('2021-12-13 00:00:00'), Timestamp('2022-01-22 00:00:00'), Timestamp('2022-02-03 00:00:00'), Timestamp('2022-02-15 00:00:00'), Timestamp('2022-02-27 00:00:00'), Timestamp('2022-03-01 00:00:00'), Timestamp('2022-03-09 00:00:00'), Timestamp('2022-05-04 00:00:00'), Timestamp('2022-05-09 00:00:00'), Timestamp('2022-06-13 00:00:00'), Timestamp('2022-06-17 00:00:00')]

# %%
def my_decompose(df, features, freq=5):
    trend = pd.DataFrame()
    seasonal = pd.DataFrame()
    resid = pd.DataFrame()
    
    for f in features:
        result = seasonal_decompose(df[f], model='additive', period=freq, extrapolate_trend=freq)
        trend[f] = result.trend.values
        seasonal[f] = result.seasonal.values
        resid[f] = result.resid.values
        
    return trend, seasonal, resid

# 각 변수별 트렌드/계절적/잔차
tdf5, sdf5, rdf5 = my_decompose(df, features=['open','high','low','close','volume K', 'rate %'], freq=5)
tdf20, sdf20, rdf20 = my_decompose(df, features=['open','high','low','close','volume K', 'rate %'], freq=20)
tdf60, sdf60, rdf60 = my_decompose(df, features=['open','high','low','close','volume K', 'rate %'], freq=60)
tdf120, sdf120, rdf120 = my_decompose(df, features=['open','high','low','close','volume K', 'rate %'], freq=120)
tdf5.describe()

fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(111)
df.close.plot(ax=ax, label='Observed', legend=True, color='k', linewidth=2)
tdf5.close.plot(ax=ax, label='Trend 5', legend=True, color='r', linewidth=1)
tdf20.close.plot(ax=ax, label='Trend 20', legend=True, color='yellow', alpha=0.5, linewidth=1)
tdf60.close.plot(ax=ax, label='Trend 60', legend=True, color='cornflowerblue', linewidth=1)
tdf120.close.plot(ax=ax, label='Trend 120', legend=True, color='green', linewidth=1)
rdf5.close.plot(ax=ax,label='Resid', legend=True)
plt.show()

# %% [markdown]
# - 그래프 개형에서도 알 수 있었지만, 21, 22년도 가격이 급등, 급락한 지점이 많아서 이상치로 많이 잡히는 것으로 판단.

# %%
rdf5.describe()
# Out:
#               open         high          low        close     volume K  \
# count  1994.000000  1994.000000  1994.000000  1994.000000  1994.000000
# mean     -0.050755     0.118222     1.936176     1.606269    -0.220746
# std     609.201809   528.556654   647.299774   610.598672   121.508831
# min   -3521.386057 -3106.777507 -6489.854542 -3532.246495  -725.701384
# 25%    -131.243941  -117.153802  -118.514534  -130.094174   -27.132658
# 50%       3.250825    -0.676040    -1.073233     2.812178    -2.208384
# 75%     128.665972   119.516445   128.689647   129.520524    24.127148
# max    3216.373943  3702.042493  4723.100523  3214.073505   796.445209
#
#             rate %
# count  1994.000000
# mean      0.009001
# std       3.756401
# min     -32.712061
# 25%      -1.959737
# 50%      -0.060696
# 75%       1.931621
# max      20.704670

# %% [markdown]
# - 변수간의 단위가 달라 이대로 학습 시킬 경우 특정 변수에 편향된 모델이 생성될 수 있음
# - 정규화 or 표준화 필요

# %%
tdf5.close
# Out:
# 0        1097.438476
# 1        1068.457333
# 2        1034.080000
# 3        1012.240000
# 4         986.620000
#             ...
# 1989    24438.580000
# 1990    22835.220000
# 1991    21620.320000
# 1992    20117.312381
# 1993    18698.838095
# Name: close, Length: 1994, dtype: float64

# %%
df['ma_5'] = tdf5.close
df['ma_20'] = tdf20.close
df['ma_60'] = tdf60.close
df['ma_120'] = tdf120.close

# %%
df
# Out:
#            date    close     open     high      low  volume K  rate %  year  \
# 0    2017-01-01    995.4    963.4   1001.6    956.1     41.15    3.33  2017
# 1    2017-01-02   1017.0    995.4   1031.7    990.2     64.95    2.17  2017
# 2    2017-01-03   1033.3   1017.0   1035.5   1006.5     54.79    1.60  2017
# 3    2017-01-04   1135.4   1033.3   1148.5   1022.3    156.27    9.88  2017
# 4    2017-01-05    989.3   1135.4   1150.6    874.5    240.01  -12.86  2017
# ...         ...      ...      ...      ...      ...       ...     ...   ...
# 1989 2022-06-13  22448.0  26606.3  26857.6  22006.3    379.26  -15.63  2022
# 1990 2022-06-14  22157.3  22449.1  23200.3  20860.9    251.01   -1.29  2022
# 1991 2022-06-15  22577.9  22137.5  22754.4  20125.8    280.41    1.90  2022
# 1992 2022-06-16  20386.6  22577.9  22942.1  20231.1    144.00   -9.71  2022
# 1993 2022-06-17  20531.8  20391.3  21315.4  20244.1    141.70    0.71  2022
#
#       month  day          ma_5         ma_20         ma_60        ma_120
# 0         1    1   1097.438476    826.676818    919.391559    187.803305
# 1         1    2   1068.457333    830.687763    922.284378    200.669738
# 2         1    3   1034.080000    834.698708    925.177198    213.536172
# 3         1    4   1012.240000    838.709653    928.070017    226.402605
# 4         1    5    986.620000    842.720597    930.962836    239.269039
# ...     ...  ...           ...           ...           ...           ...
# 1989      6   13  24438.580000  29164.651146  29481.454744  31454.351336
# 1990      6   14  22835.220000  29132.754617  29318.584317  31358.282402
# 1991      6   15  21620.320000  29100.858088  29155.713890  31262.213467
# 1992      6   16  20117.312381  29068.961558  28992.843463  31166.144532
# 1993      6   17  18698.838095  29037.065029  28829.973036  31070.075598
#
# [1994 rows x 14 columns]

# %%
df['candle'] = df['high'] - df['low']
df
# Out:
#            date    close     open     high      low  volume K  rate %  year  \
# 0    2017-01-01    995.4    963.4   1001.6    956.1     41.15    3.33  2017
# 1    2017-01-02   1017.0    995.4   1031.7    990.2     64.95    2.17  2017
# 2    2017-01-03   1033.3   1017.0   1035.5   1006.5     54.79    1.60  2017
# 3    2017-01-04   1135.4   1033.3   1148.5   1022.3    156.27    9.88  2017
# 4    2017-01-05    989.3   1135.4   1150.6    874.5    240.01  -12.86  2017
# ...         ...      ...      ...      ...      ...       ...     ...   ...
# 1989 2022-06-13  22448.0  26606.3  26857.6  22006.3    379.26  -15.63  2022
# 1990 2022-06-14  22157.3  22449.1  23200.3  20860.9    251.01   -1.29  2022
# 1991 2022-06-15  22577.9  22137.5  22754.4  20125.8    280.41    1.90  2022
# 1992 2022-06-16  20386.6  22577.9  22942.1  20231.1    144.00   -9.71  2022
# 1993 2022-06-17  20531.8  20391.3  21315.4  20244.1    141.70    0.71  2022
#
#       month  day          ma_5         ma_20         ma_60        ma_120  \
# 0         1    1   1097.438476    826.676818    919.391559    187.803305
# 1         1    2   1068.457333    830.687763    922.284378    200.669738
# 2         1    3   1034.080000    834.698708    925.177198    213.536172
# 3         1    4   1012.240000    838.709653    928.070017    226.402605
# 4         1    5    986.620000    842.720597    930.962836    239.269039
# ...     ...  ...           ...           ...           ...           ...
# 1989      6   13  24438.580000  29164.651146  29481.454744  31454.351336
# 1990      6   14  22835.220000  29132.754617  29318.584317  31358.282402
# 1991      6   15  21620.320000  29100.858088  29155.713890  31262.213467
# 1992      6   16  20117.312381  29068.961558  28992.843463  31166.144532
# 1993      6   17  18698.838095  29037.065029  28829.973036  31070.075598
#
#       candle
# 0       45.5
# 1       41.5
# 2       29.0
# 3      126.2
# 4      276.1
# ...      ...
# 1989  4851.3
# 1990  2339.4
# 1991  2628.6
# 1992  2711.0
# 1993  1071.3
#
# [1994 rows x 15 columns]

# %%
fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(111)
df.close[-600:].plot(ax=ax, label='Observed', legend=True, color='k', linewidth=2)
df.ma_5[-600:].plot(ax=ax, label='Trend 5', legend=True, color='r', linewidth=1)
df.ma_20[-600:].plot(ax=ax, label='Trend 20', legend=True, color='yellow', alpha=0.5, linewidth=1)
df.ma_60[-600:].plot(ax=ax, label='Trend 60', legend=True, color='cornflowerblue', linewidth=1)
df.ma_120[-600:].plot(ax=ax, label='Trend 120', legend=True, color='green', linewidth=1)
df.candle[-600:].plot(ax=ax, label='candle volume', legend=True)
plt.show()

# %%
df['shift_down'] = df.candle.shift(1).fillna(0)
df['candle_rate_%'] = (df['candle'] - df['shift_down'])/df['shift_down']*100
df = df.drop(['shift_down'], axis=1)
df
# Out:
#            date    close     open     high      low  volume K  rate %  year  \
# 0    2017-01-01    995.4    963.4   1001.6    956.1     41.15    3.33  2017
# 1    2017-01-02   1017.0    995.4   1031.7    990.2     64.95    2.17  2017
# 2    2017-01-03   1033.3   1017.0   1035.5   1006.5     54.79    1.60  2017
# 3    2017-01-04   1135.4   1033.3   1148.5   1022.3    156.27    9.88  2017
# 4    2017-01-05    989.3   1135.4   1150.6    874.5    240.01  -12.86  2017
# ...         ...      ...      ...      ...      ...       ...     ...   ...
# 1989 2022-06-13  22448.0  26606.3  26857.6  22006.3    379.26  -15.63  2022
# 1990 2022-06-14  22157.3  22449.1  23200.3  20860.9    251.01   -1.29  2022
# 1991 2022-06-15  22577.9  22137.5  22754.4  20125.8    280.41    1.90  2022
# 1992 2022-06-16  20386.6  22577.9  22942.1  20231.1    144.00   -9.71  2022
# 1993 2022-06-17  20531.8  20391.3  21315.4  20244.1    141.70    0.71  2022
#
#       month  day          ma_5         ma_20         ma_60        ma_120  \
# 0         1    1   1097.438476    826.676818    919.391559    187.803305
# 1         1    2   1068.457333    830.687763    922.284378    200.669738
# 2         1    3   1034.080000    834.698708    925.177198    213.536172
# 3         1    4   1012.240000    838.709653    928.070017    226.402605
# 4         1    5    986.620000    842.720597    930.962836    239.269039
# ...     ...  ...           ...           ...           ...           ...
# 1989      6   13  24438.580000  29164.651146  29481.454744  31454.351336
# 1990      6   14  22835.220000  29132.754617  29318.584317  31358.282402
# 1991      6   15  21620.320000  29100.858088  29155.713890  31262.213467
# 1992      6   16  20117.312381  29068.961558  28992.843463  31166.144532
# 1993      6   17  18698.838095  29037.065029  28829.973036  31070.075598
#
#       candle  candle_rate_%
# 0       45.5            inf
# 1       41.5      -8.791209
# 2       29.0     -30.120482
# 3      126.2     335.172414
# 4      276.1     118.779715
# ...      ...            ...
# 1989  4851.3     151.558206
# 1990  2339.4     -51.777874
# 1991  2628.6      12.362144
# 1992  2711.0       3.134749
# 1993  1071.3     -60.483217
#
# [1994 rows x 16 columns]

# %%
fig = plt.figure(figsize=(15,7))
ax = fig.add_subplot(211)
df.close[-900:-600].plot(ax=ax, label='Observed', legend=True, color='k', linewidth=2)
df.ma_5[-900:-600].plot(ax=ax, label='Trend 5', legend=True, color='r', linewidth=1)
df.ma_20[-900:-600].plot(ax=ax, label='Trend 20', legend=True, color='yellow', alpha=0.5, linewidth=1)
df.ma_60[-900:-600].plot(ax=ax, label='Trend 60', legend=True, color='cornflowerblue', linewidth=1)
df.ma_120[-900:-600].plot(ax=ax, label='Trend 120', legend=True, color='green', linewidth=1)

ax2 = fig.add_subplot(212)
df['candle'][-900:-600].plot.bar(ax=ax2, label='candle rate', legend=True)
plt.show()

# %%
def golden(data):
    temp = data.copy()
    temp['shift_down_5'] = temp['ma_5'].shift(1).fillna(0)
    temp['shift_down_120'] = temp['ma_120'].shift(1).fillna(0)
    
    golden_list = list()
    for idx in temp.index:
        if (temp.iloc[idx]['shift_down_5'] < temp.iloc[idx]['shift_down_120']) and (temp.iloc[idx]['ma_5'] >= temp.iloc[idx]['ma_120']):
            golden_list.append(1)
        else:
            golden_list.append(0)
    return golden_list

def dead(data):
    temp = data.copy()
    temp['shift_down_5'] = temp['ma_5'].shift(1).fillna(0)
    temp['shift_up_5'] = temp['ma_5'].shift(-1).fillna(0)
    temp['shift_down_120'] = temp['ma_120'].shift(1).fillna(0)
    temp['shift_up_120'] = temp['ma_120'].shift(-1).fillna(0)
    
    dead_list = list()
    for idx in temp.index:
        if (temp.iloc[idx]['shift_down_5'] > temp.iloc[idx]['shift_down_120']) and (temp.iloc[idx]['ma_5'] <= temp.iloc[idx]['ma_120']):
            dead_list.append(1)
        else:
            dead_list.append(0)
    return dead_list

# %%
df['golden_cross'] = golden(df)
df['dead_cross'] = dead(df)

# %%
fig = plt.figure(figsize=(15,7))

temp = df[-1000:]

ax = fig.add_subplot(111)
temp.close.plot(ax=ax, label='Observed', legend=True, color='k', linewidth=1)
temp['ma_5'].plot(ax=ax, label='Trend 5', legend=True, color='cornflowerblue', linewidth=1)
temp['ma_120'].plot(ax=ax, label='Trend 120', legend=True, color='green', linewidth=1)

ax.scatter(temp[temp['golden_cross']==1].index, temp[temp['golden_cross']==1]['close'], marker='o', s=50, color='b')
ax.scatter(temp[temp['dead_cross']==1].index, temp[temp['dead_cross']==1]['close'], marker='x', s=50, color='r')

# df[df['golden_cross'] == 1].close.plot.scatter(ax=ax, label='golden cross', legend=True, color='blue', marker='o')
plt.grid(True)
plt.show()

# %% [markdown]
# #### golden cross와 dead cross에 여유치를 넣어야 할듯

# %% [markdown]
# ### Splitting data

# %%
# time series 데이터이므로 window_size 별로 잘라서 x, y로 구성할 필요가 있음
# 예를 들어, 종가가
# [10,20,30,40, 50,60,70,80,90] 이렇게 데이터가 있다고 한다면
# x=[10,20,30], y=[40]
# x=[20,30,40], y=[50]
# x=[30,40,50], y=[60] 즉 (이전 3일치 데이터)로 (이후 1일의 데이터)를 예측하는 구조가 필요

# data를 split 할 n일에 대한 기준이 필요할 듯
df = df.drop('date', axis=1)

def split_sequence(data, n_steps):
    X, y = list(), list()
    for i in range(len(data)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the sequence
        if end_ix > len(data)-1:
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = data[i:end_ix], data['close'][end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
x,y = split_sequence(df, 3)
print(x[-1:])
print(y[-1])
# Out:
# [[[ 2.21573000e+04  2.24491000e+04  2.32003000e+04  2.08609000e+04
#     2.51010000e+02 -1.29000000e+00  2.02200000e+03  6.00000000e+00
#     1.40000000e+01  2.28352200e+04  2.91327546e+04  2.93185843e+04
#     3.13582824e+04  2.33940000e+03 -5.17778740e+01  0.00000000e+00
#     0.00000000e+00]
#   [ 2.25779000e+04  2.21375000e+04  2.27544000e+04  2.01258000e+04
#     2.80410000e+02  1.90000000e+00  2.02200000e+03  6.00000000e+00
#     1.50000000e+01  2.16203200e+04  2.91008581e+04  2.91557139e+04
#     3.12622135e+04  2.62860000e+03  1.23621441e+01  0.00000000e+00
#     0.00000000e+00]
#   [ 2.03866000e+04  2.25779000e+04  2.29421000e+04  2.02311000e+04
#     1.44000000e+02 -9.71000000e+00  2.02200000e+03  6.00000000e+00
#     1.60000000e+01  2.01173124e+04  2.90689616e+04  2.89928435e+04
#     3.11661445e+04  2.71100000e+03  3.13474854e+00  0.00000000e+00
#     0.00000000e+00]]]
# 20531.8

# %%
df.tail(5)
# Out:
#         close     open     high      low  volume K  rate %  year  month  day  \
# 1989  22448.0  26606.3  26857.6  22006.3    379.26  -15.63  2022      6   13
# 1990  22157.3  22449.1  23200.3  20860.9    251.01   -1.29  2022      6   14
# 1991  22577.9  22137.5  22754.4  20125.8    280.41    1.90  2022      6   15
# 1992  20386.6  22577.9  22942.1  20231.1    144.00   -9.71  2022      6   16
# 1993  20531.8  20391.3  21315.4  20244.1    141.70    0.71  2022      6   17
#
#               ma_5         ma_20         ma_60        ma_120  candle  \
# 1989  24438.580000  29164.651146  29481.454744  31454.351336  4851.3
# 1990  22835.220000  29132.754617  29318.584317  31358.282402  2339.4
# 1991  21620.320000  29100.858088  29155.713890  31262.213467  2628.6
# 1992  20117.312381  29068.961558  28992.843463  31166.144532  2711.0
# 1993  18698.838095  29037.065029  28829.973036  31070.075598  1071.3
#
#       candle_rate_%  golden_cross  dead_cross
# 1989     151.558206             0           0
# 1990     -51.777874             0           0
# 1991      12.362144             0           0
# 1992       3.134749             0           0
# 1993     -60.483217             0           0

# %%
from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.2, random_state=17)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(n_estimators=500)

forest.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_580/1430896353.py in <module>
#       3 forest = RandomForestRegressor(n_estimators=500)
#       4
# ----> 5 forest.fit(x_train, y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302                 "sparse multilabel-indicator for y is not supported."
#     303             )
# --> 304         X, y = self._validate_data(X, y, multi_output=True,
#     305                                    accept_sparse="csc", dtype=DTYPE)
#     306         if sample_weight is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     714                     "into decimal numbers with dtype='numeric'") from e
#     715         if not allow_nd and array.ndim >= 3:
# --> 716             raise ValueError("Found array with dim %d. %s expected <= 2."
#     717                              % (array.ndim, estimator_name))
#     718
#
# ValueError: Found array with dim 3. Estimator expected <= 2.

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X, y, epochs=200, verbose=0)
# demonstrate prediction
x_input = array([70, 80, 90])
x_input = x_input.reshape((1, n_steps, n_features))
yhat = model.predict(x_input, verbose=0)
print(yhat)
